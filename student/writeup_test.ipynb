# %% [markdown]
# # Q2

# %% [markdown]
# ## Q2.1

# %%
# Q2.1.a: what unicode char does chr(0) return?
chr(0)
# Out:
# '\x00'

# %%
# Q2.1.b: How des string representation differ from printed representation
print(chr(0).__repr__())
print(chr(0).__str__())
# Out:
# '\x00'

# %%
# Q2.1.c
chr(0)
# Out:
# '\x00'

# %%
print(chr(0))

# %%
"this is a test" + chr(0) + "string"
# Out:
# 'this is a test\x00string'

# %%
print("this is a test" + chr(0) + "string")
# Out:
# this is a teststring

# %% [markdown]
# ## Q2.2

# %%
# Q2.2.a.
test = "Hello world!"
test_utf8 = test.encode("utf-8")
test_utf16 = test.encode("utf-16")
test_utf32 = test.encode("utf-32")

# %%
len(list(test_utf8))
# Out:
# 12

# %%
len(list(test_utf16))
# Out:
# 26

# %%
len(list(test_utf32))
# Out:
# 52

# %%
# Q2.2.b:
def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
    return "".join([bytes([b]).decode("utf-8") for b in bytestring])

# %%
decode_utf8_bytes_to_str_wrong("hello".encode("utf-8"))
# Out:
# 'hello'

# %%
decode_utf8_bytes_to_str_wrong("こんにちは".encode("utf-8"))
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 decode_utf8_bytes_to_str_wrong("こ".encode("utf-8"))
#
# Cell In[9], line 3, in decode_utf8_bytes_to_str_wrong(bytestring)
#       2 def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
# ----> 3     return "".join([bytes([b]).decode("utf-8") for b in bytestring])
#
# Cell In[9], line 3, in <listcomp>(.0)
#       2 def decode_utf8_bytes_to_str_wrong(bytestring: bytes):
# ----> 3     return "".join([bytes([b]).decode("utf-8") for b in bytestring])
#
# UnicodeDecodeError: 'utf-8' codec can't decode byte 0xe3 in position 0: unexpected end of data

# %%
# Q2.2.c:
"こ".encode("utf-8")
# Out:
# b'\xe3\x81\x93'

# %%
b'\xe3\x81'.decode("utf-8")
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 b'\xe3\x81'.decode("utf-8")
#
# UnicodeDecodeError: 'utf-8' codec can't decode bytes in position 0-1: unexpected end of data

# %% [markdown]
# ## Q2.4

# %%
PAT = r"""'(?:[sdmt]|ll|ve|re)| ?\p{L}+| ?\p{N}+| ?[^\s\p{L}\p{N}]+|\s+(?!\S)|\s+"""

# %%
import regex as re
re.findall(PAT, "some text that i'll pre-tokenize")
# Out:
# ['some', ' text', ' that', ' i', "'ll", ' pre', '-', 'tokenize']
